# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from welly import Well, Project

import os
# Out:
# /home/jackww/.VEnv/CoreData/lib/python3.14/site-packages/welly/__init__.py:69: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import get_distribution, DistributionNotFound

# %%
#Set data directory
os.chdir ("/home/jackww/Documents/VICCO/Wellbore_Core/DISCOS_ALL/")

# %%
# w = Well.from_las('15_5-4/LOGS/15_5-4_HQLD_X_2C1__35-1__15-5-4__MWD-RSN-NGS__COMPOSITED__1.LAS')  # Load a single well.
# # p = Project.from_las('my_wells/*.las')     # Load lots of wells.

# gr = w.data['CGR']  # One log...
# gr.plot()          # ...with some superpowers!

# %%
fig, (ax1) = plt.subplots(nrows=1, ncols=1, figsize=(2, 10), sharey=True)

w1 = Well.from_las('24_6-2/LOGS/24_6-2__LOGS__4C-SINAS__1754-1__24-6-2__WLC_COMPOSITE__1.LAS')

gr1 = w1.data['GR']

sub1 = gr1[1905:2054]

sub1.plot_2d(ax=ax1, cmap='viridis_r', curve=True, lw=0.3, edgecolor='k')
# Out:
# <Axes: >

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(10, 10))

w1 = Well.from_las('15_5-4/LOGS/15_5-4_HQLD_HYB_UN_2C1__14-1__15-5-4__COMPOSITE__1.LAS') #15-5-4
w2 = Well.from_las('25_7-5/LOGS/25_7-5_4C-SINAS__956-1__25-7-5__COMPOSITE__1.LAS') #25-7-5


gr1 = w1.data['HGR']
gr2 = w2.data['HGR']


sub1 = gr1[2106:2120]
sub2 = gr2[1977:2025]


sub1.plot_2d(ax=ax1, cmap='viridis_r', curve=True, lw=0.3, edgecolor='k')
sub2.plot_2d(ax=ax2, cmap='viridis_r', curve=True, lw=0.3, edgecolor='k')


# for ax in [ax1, ax2, ax3, ax4, ax5, ax6]:
#     ax.set_xlim(0, 160)

plt.xlabel("Gama")
plt.ylabel("metres")

fig.savefig('/home/jackww/Documents/VICCO/Inkscape/Logs/Gama_Logs/Logs_All_R1.svg', bbox_inches='tight', dpi=400)

# %%
fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(nrows=1, ncols=6, figsize=(10, 10))

w1 = Well.from_las('15_5-4/LOGS/15_5-4_HQLD_HYB_UN_2C1__14-1__15-5-4__COMPOSITE__1.LAS') #15-5-4
w2 = Well.from_las('25_7-5/LOGS/25_7-5_4C-SINAS__956-1__25-7-5__COMPOSITE__1.LAS') #25-7-5
w3 = Well.from_las('25_11-23/LOGS/25_11-23_OOPC1990__154-1__25-11-23__COMPOSITE__1.LAS') #25-11-23
w4 = Well.from_las('25_2-9/LOGS/25_2-9_HQLD_HYB_PUB_2C1__703-1__25-2-9__COMPOSITE__1.LAS') #25-2-9
w5 = Well.from_las('25_2-8/LOGS/25_2-8_HQLD_HYB_PUB_2C1__853-1__25-2-8__COMPOSITE__1.LAS') #25-2-8
w6 = Well.from_las('25_1-7/LOGS/25_1-7_HQLD_HYB_PUB_2C1__693-1__25-1-7__COMPOSITE__1.LAS') #25/1=7

gr1 = w1.data['HGR']
gr2 = w2.data['HGR']
gr3 = w3.data['GR']
gr4 = w4.data['HGR']
gr5 = w5.data['HGR']
gr6 = w6.data['HGR']

sub1 = gr1[2106:2146]
sub2 = gr2[1977:2085]
sub3 = gr3[1719:1765.5]
sub4 = gr4[2220:2255.9]
sub5 = gr5[2200:2210.7]
sub6 = gr6[2233:2267]

sub1.plot_2d(ax=ax1, cmap='viridis_r', curve=True, lw=0.3, edgecolor='k')
sub2.plot_2d(ax=ax2, cmap='viridis_r', curve=True, lw=0.3, edgecolor='k')
sub3.plot_2d(ax=ax3, cmap='viridis_r', curve=True, lw=0.3, edgecolor='k')
sub4.plot_2d(ax=ax4, cmap='viridis_r', curve=True, lw=0.3, edgecolor='k')
sub5.plot_2d(ax=ax5, cmap='viridis_r', curve=True, lw=0.3, edgecolor='k')
sub6.plot_2d(ax=ax6, cmap='viridis_r', curve=True, lw=0.3, edgecolor='k')

# for ax in [ax1, ax2, ax3, ax4, ax5, ax6]:
#     ax.set_xlim(0, 160)

plt.xlabel("Gama")
plt.ylabel("metres")

fig.savefig('/home/jackww/Documents/VICCO/Inkscape/Logs/Gama_Logs/Logs_All_R1.svg', bbox_inches='tight', dpi=400)

# %%
fig, (ax4, ax5, ax6) = plt.subplots(nrows=1, ncols=3, figsize=(5, 10))


w4 = Well.from_las('25_2-9/LOGS/25_2-9_HQLD_HYB_PUB_2C1__703-1__25-2-9__COMPOSITE__1.LAS') #25-2-9
w5 = Well.from_las('25_2-8/LOGS/25_2-8_HQLD_HYB_PUB_2C1__853-1__25-2-8__COMPOSITE__1.LAS') #25-2-8
w6 = Well.from_las('25_1-7/LOGS/25_1-7_HQLD_HYB_PUB_2C1__693-1__25-1-7__COMPOSITE__1.LAS') #25/1=7


gr4 = w4.data['HGR']
gr5 = w5.data['HGR']
gr6 = w6.data['HGR']


sub4 = gr4[2220:2272]
sub5 = gr5[2200:2250]
sub6 = gr6[2233:2290]

sub4.plot_2d(ax=ax4, cmap='viridis_r', curve=True, lw=0.3, edgecolor='k')
sub5.plot_2d(ax=ax5, cmap='viridis_r', curve=True, lw=0.3, edgecolor='k')
sub6.plot_2d(ax=ax6, cmap='viridis_r', curve=True, lw=0.3, edgecolor='k')

# for ax in [ax1, ax2, ax3, ax4, ax5, ax6]:
#     ax.set_xlim(0, 160)

plt.xlabel("Gama")
plt.ylabel("metres")

fig.savefig('/home/jackww/Documents/VICCO/Inkscape/Logs/Gama_Logs/Logs_All_Pandion_Long.svg', bbox_inches='tight', dpi=400)

# %%
w = Well.from_las('25_7-5/LOGS/25_7-5_4C-SINAS__956-1__25-7-5__COMPOSITE__1.LAS')  # Load a single well.

fig, (ax1, ax2, ax3, ax4, ax5, ax6) = plt.subplots(nrows=1, ncols=6, figsize=(10, 10))

D1 = w.data['HGR']
D2 = w.data['HPHI']
D3 = w.data['HRD']
D4 = w.data['HRHO']
D5 = w.data['HRM']
D6 = w.data['HRS']

sub1 = D1[1977:2085]
sub2 = D2[1977:2085]
sub3 = D3[1977:2085]
sub4 = D4[1977:2085]
sub5 = D5[1977:2085]
sub6 = D6[1977:2085]

sub1.plot_2d(ax=ax1, cmap='viridis_r', curve=True, lw=0.3, edgecolor='k')
sub2.plot_2d(ax=ax2, cmap='viridis_r', curve=True, lw=0.3, edgecolor='k')
sub3.plot_2d(ax=ax3, cmap='viridis_r', curve=True, lw=0.3, edgecolor='k')
sub4.plot_2d(ax=ax4, cmap='viridis_r', curve=True, lw=0.3, edgecolor='k')
sub5.plot_2d(ax=ax5, cmap='viridis_r', curve=True, lw=0.3, edgecolor='k')
sub6.plot_2d(ax=ax6, cmap='viridis_r', curve=True, lw=0.3, edgecolor='k')

# for ax in [ax1, ax2, ax3, ax4, ax5, ax6]:
#     ax.set_xlim(0, 160)

plt.xlabel("Gama")
plt.ylabel("metres")
# Out:
# Text(821.1111111111113, 0.5, 'metres')

# %%
segment = gr.to_basis(start=1977, stop=2085)

fig, axs = plt.subplots(ncols=2)

# The original log on the left.
segment.plot(ax=axs[0], c='r')
axs[0].axvline(80, c='c', alpha=0.7)

# Make and plot a blocked version.
segment.block(cutoffs=100).plot(ax=axs[1])
axs[1].set_xlabel('')
# Out:
# Text(0.5, 0, '')

# %%
fig, ax = plt.subplots(figsize=(2, 10))

segment.plot(ax=ax)
segment.block(cutoffs=(100, 130), values=(120, 140, 160)).plot(ax=ax)
# Out:
# <Axes: title={'center': 'HGR'}, xlabel='GAPI'>
